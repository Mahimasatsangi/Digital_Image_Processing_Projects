# %%
from IPython.display import Image
Image("cp.JPG", width=200, height=200)

# %%
import matplotlib, cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('cp.JPG')
print(img)
# Out:
# [[[12 12 12]
#   [ 9  9  9]
#   [11 11 11]
#   ...
#   [ 6 10 11]
#   [ 6 10 11]
#   [ 6 10 11]]
#
#  [[16 16 16]
#   [16 16 16]
#   [19 19 19]
#   ...
#   [11 13 14]
#   [ 8 10 11]
#   [ 5  7  8]]
#
#  [[10 10 10]
#   [14 14 14]
#   [20 20 20]
#   ...
#   [13 15 16]
#   [ 9 11 12]
#   [ 4  6  7]]
#
#  ...
#
#  [[57 56 58]
#   [45 44 46]
#   [24 23 25]
#   ...
#   [18 20 20]
#   [ 9 11 11]
#   [19 21 21]]
#
#  [[15 14 16]
#   [16 15 17]
#   [ 9  8 10]
#   ...
#   [17 19 19]
#   [20 22 22]
#   [18 20 20]]
#
#  [[ 6  5  7]
#   [ 4  3  5]
#   [ 1  0  2]
#   ...
#   [16 18 18]
#   [26 28 28]
#   [ 4  6  6]]]

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
print(gray_img)
# Out:
# [[132 131 128 ...  51  52  51]
#  [139 138 134 ...  53  53  51]
#  [139 138 138 ...  55  53  51]
#  ...
#  [213 211 211 ... 138 143 150]
#  [213 212 212 ... 137 144 151]
#  [212 212 212 ... 135 144 149]]

# %%
plt.imshow(cv2.cvtColor(gray_img, cv2.COLOR_GRAY2RGB))

# %%
average_color_per_row = np.average(img, axis=0)
average_color = np.average(average_color_per_row, axis=0)
average_color = np.uint8(average_color)
print(average_color)
# Out:
# [173 146 142]

# %%
average_color_img = np.array([[average_color]*100]*100, np.uint8)
plt.imshow(average_color_img)

# %%
_, threshold_img = cv2.threshold(gray_img, 60, 255, cv2.THRESH_BINARY)
threshold_img = cv2.cvtColor(threshold_img, cv2.COLOR_GRAY2RGB)
plt.figure(figsize=(10,10))
plt.imshow(threshold_img)

# %%
img = cv2.imread('cp.JPG')

img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)

# equalize the histogram of the Y channel
img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])

# convert the YUV image back to RGB format
img_output = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)

small_I = cv2.resize(img, (0,0), fx=0.5, fy=0.5) 
small_O = cv2.resize(img, (0,0), fx=0.5, fy=0.5) 

cv2.imshow('Color input image', small_I)
cv2.imshow('Histogram equalized', small_O)
cv2.waitKey(0)
